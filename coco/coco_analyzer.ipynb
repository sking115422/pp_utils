# %%
import json
from collections import Counter
import pandas as pd
import os

# %%
in_dir = "/mnt/nis_lab_research/data/coco_files/merged/far_shah_b1-b5_b8_train/result.json"
# out_dir = "./output"
out_dir = in_dir[0:-11]

# %%
with open(in_dir) as f:
    coco_json_obj = json.load(f)

# %%
ann_list = coco_json_obj["annotations"]
cat_list = coco_json_obj["categories"]
img_list = coco_json_obj["images"]

# %%
# Getting overall coco breakdown

cat_occ_list = []
for ann in ann_list:
    cat_occ_list.append(ann["category_id"])
    
cat_keys = Counter(cat_occ_list).keys()
cat_vals = Counter(cat_occ_list).values()

cat_prcnt = []
vals_tot = sum(list(cat_vals))
for val in list(cat_vals):
    cat_prcnt.append(val/vals_tot)

cat_name_list = []
for key in cat_keys:
    for item in cat_list:
        if key == item["id"]:
            cat_name_list.append(item["name"])

df_tot = pd.DataFrame({"cat_key": list(cat_keys), "cat_name": cat_name_list, "cat_count": list(cat_vals), "cat_prcnt": cat_prcnt}).sort_values(by="cat_count", ascending=False)

df_tot
# Out:
#     cat_key            cat_name  cat_count  cat_prcnt
# 5        10      General Button     100322   0.717195
# 0        14                Logo      13559   0.096932
# 8        20       Search Button       4393   0.031405
# 1        13        Login Button       3785   0.027059
# 6         3  Alert Notification       3283   0.023470
# 14        7        Close Button       2473   0.017679
# 10       21    Search Input Box       2390   0.017086
# 20        0       Accept Button       1532   0.010952
# 11        2       Advertisement       1224   0.008750
# 17       18         Play Button        885   0.006327
# 9        26               Video        864   0.006177
# 15       19               Popup        821   0.005869
# 4        11   General Input Box        727   0.005197
# 7         5            Checkbox        723   0.005169
# 3         9     Email Input Box        605   0.004325
# 22        8     Download Button        593   0.004239
# 2        15      Name Input Box        475   0.003396
# 23       16  Password Input Box        285   0.002037
# 19       24       Toggle Button        255   0.001823
# 18        4        Allow Button        218   0.001558
# 12       22       Submit Button        178   0.001273
# 25       17     Phone Input Box         99   0.000708
# 21        6       Click Captcha         96   0.000686
# 16        1   Address Input Box         74   0.000529
# 24       25       Update Button         17   0.000122
# 26       23        Text Captcha          3   0.000021
# 13       12       Image Captcha          2   0.000014

# %%
# Exporting overall breakdown to CSV

df_tot.to_csv(os.path.join(out_dir, "coco_ann_tot.csv"))

# %%
# Getting individual img analysis

f = open(os.path.join(out_dir, "coco_ann_full.txt"), "w+")
f.write("FULL COCO JSON FILE ANALYSIS\n\n")

img_id_list = []

for item in img_list: 
    img_id_list.append([item["id"], item["file_name"]])

for each in img_id_list:
    
    f.write("Image " + str(each[0]) + " > " + each[1] + "\n")
    single_img_list = []
    
    for item in ann_list:
        if each[0] == item["image_id"]:
            single_img_list.append(item["category_id"])
            cat_keys = Counter(single_img_list).keys()
            cat_vals = Counter(single_img_list).values()

            cat_name_list = []
            for key in cat_keys:
                for thing in cat_list:
                    if key == thing["id"]:
                        cat_name_list.append(thing["name"])
    
    for i in range(0, len(cat_keys)):
        f.write("   " + str(list(cat_keys)[i]) + " " + cat_name_list[i] + " > " + str(list(cat_vals)[i]) + "\n")
        
    f.write("\n")
       
f.close()
